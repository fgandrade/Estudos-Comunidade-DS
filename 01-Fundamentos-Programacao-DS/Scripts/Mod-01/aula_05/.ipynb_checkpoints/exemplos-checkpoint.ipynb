# %% [markdown]
# # CÓDIGOS AUXILIARES

# %% [markdown]
# ## Carregamento de Imagens

# %%
from IPython.display import Image

# %% [markdown]
# # EXEMPLO 1

# %% [markdown]
# ## Problema

# %% [markdown]
# O teorema de Pitágoras é uma relação matemática entre os comprimentos dos lados de qualquer triângulo retângulo. Na geometria euclidiana, o teorema afirma que:
#
#
# ```javascript
# "Em qualquer triângulo retângulo, o quadrado do comprimento da hipotenusa é igual à soma dos quadrados dos comprimentos dos catetos."
# ```

# %%
Image('img/exemplo1.png')

# %% [markdown]
# Crie uma função que receba 3 valores que representarão os lados de um triângulo. Considere que não importa a ordem que serão fornecidos os valores, podendo ser fornecido primeiro a hipotenusa e depois os catetos, ou primeiro os catetos e depois a hipotenusa, etc.
#
# Dados os 3 valores, imprima na tela se trata-se de um triângulo-retângulo ou não.
#
# Utilize a função assert para testar os resultados.

# %% [markdown]
# ## Análise

# %% [markdown]
# Análise Aqui

# %% [markdown]
# ## Implicações / Proposições / Afirmações

# %% [markdown]
# Implicações aqui

# %% [markdown]
# ## Resolução e Resposta

# %%
# Resolução aqui
def triangulo(v1, v2, v3):
    lados = [v1, v2, v3]
    
    hip = max(lados)
    lados.remove(hip)
    
    lad1 = lados[0]
    lad2 = lados[1]
    
    if hip ** 2 == (lad1 ** 2 + lad2 ** 2):
        return True
    else:
        return False

# %%
assert triangulo(3, 4, 5), 'Os valores não formam um triangulo retângulo'

# %%
assert triangulo(5, 3, 4), 'Os valores não formam um triangulo retângulo'

# %%
assert triangulo(4, 5, 3), 'Os valores não formam um triangulo retângulo'

# %%
assert triangulo(3, 10, 5), 'Os valores não formam um triangulo retângulo'
# Out:
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# /tmp/ipykernel_52467/88609952.py in <module>
# ----> 1 assert triangulo(3, 10, 5), 'Os valores não formam um triangulo retângulo'
#
# AssertionError: Os valores não formam um triangulo retângulo

# %% [markdown]
# # EXEMPLO 2

# %% [markdown]
# ## Problema

# %% [markdown]
# Considere as seguinte fórmulas:

# %%
Image('img/exemplo2_1.png')

# %%
Image('img/exemplo2_2.png')

# %% [markdown]
# Escreva as funções F(n) e G(n) de acordo com as suas respectivas fórmulas. Escreva uma função K(n) que receba um inteiro n > 0 e devolva F(n) e G(n).
#
# * Para K(2), a função deve devolver os valores 1 e 2
# * Para K(3), a função deve devolver os valores 3 e 8
# * Para K(4), a função deve devolver os valores 8 e 11
#
# O domínio das funções K(n) são os números naturais (n ∈ ℕ, n > 0).
#
# Imprima uma lista de resultados (F(n), G(n)) para K(n) entre 1 e 5.
#
# Utilize a função assert para verificar o resultado das funções.
#
# Utilize também a função try .. catch junto com função assert, na criação da função K para verificar se o parâmetro passado é um valor inteiro.

# %% [markdown]
# ## Análise

# %% [markdown]
# Análise Aqui

# %% [markdown]
# ## Implicações / Proposições / Afirmações

# %% [markdown]
# Implicações aqui

# %% [markdown]
# ## Resolução e Resposta

# %%
# Resolução aqui
def f(i):
    if i == 1:
        return 2
    elif i == 2:
        return 1
    else:
        return 2 * f(i-1) + g(i-2)

# %%
def g(i):
    if i < 3:
        return i
    else:
        return g(i-1) + 3 * f(i-2)

# %%
def k(i):
    try:
        assert isinstance(i, int)
#         assert (isinstance(i, int) and i > 0)
#         conv = int(i)
    except:
        print(f'O valor de i deve ser inteiro e maior do que zero')
    else:
#         return ( f(int(i)), g(int(i)) )
#         return ( f(conv), g(conv) )
        return ( f(i), g(i) )

# %%
retorno = []

for i in range(1, 6):
    retorno.append(k(i))
    
retorno
# Out:
# [(2, 1), (1, 2), (3, 8), (8, 11), (24, 20)]

# %%
assert k(2) == (1, 2), 'Erro da função'

# %%
assert k('3') == (3, 8), 'Erro da função'
# Out:
# O valor de i deve ser inteiro e maior do que zero
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# /tmp/ipykernel_52467/3453529187.py in <module>
# ----> 1 assert k('3') == (3, 8), 'Erro da função'
#
# AssertionError: Erro da função

# %%
assert k(4.4) == (8, 11), 'Erro da função'
# Out:
# O valor de i deve ser inteiro e maior do que zero
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# /tmp/ipykernel_52467/2170133398.py in <module>
# ----> 1 assert k(4.4) == (8, 11), 'Erro da função'
#
# AssertionError: Erro da função

# %%
assert k('Pedro') == (8, 11), 'Erro da função'
# Out:
# O valor de i deve ser inteiro e maior do que zero
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# /tmp/ipykernel_52467/1235868076.py in <module>
# ----> 1 assert k('Pedro') == (8, 11), 'Erro da função'
#
# AssertionError: Erro da função

# %%
assert k(0) == (8, 11), 'Erro da função'
# Out:
# ---------------------------------------------------------------------------
# RecursionError                            Traceback (most recent call last)
# /tmp/ipykernel_52467/3013317461.py in <module>
# ----> 1 assert k(0) == (8, 11), 'Erro da função'
#
# /tmp/ipykernel_52467/518268500.py in k(i)
#       9 #         return ( f(int(i)), g(int(i)) )
#      10 #         return ( f(conv), g(conv) )
# ---> 11         return ( f(i), g(i) )
#
# /tmp/ipykernel_52467/894911891.py in f(i)
#       6         return 1
#       7     else:
# ----> 8         return 2 * f(i-1) + g(i-2)
#
# ... last 1 frames repeated, from the frame below ...
#
# /tmp/ipykernel_52467/894911891.py in f(i)
#       6         return 1
#       7     else:
# ----> 8         return 2 * f(i-1) + g(i-2)
#
# RecursionError: maximum recursion depth exceeded in comparison

# %%
Para K(2), a função deve devolver os valores 1 e 2
Para K(3), a função deve devolver os valores 3 e 8
Para K(4), a função deve devolver os valores 8 e 11
